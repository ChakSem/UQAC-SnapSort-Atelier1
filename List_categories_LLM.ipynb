# %%
from LLM_pipeline_V2 import LLMCall, ClusteringManager
import base64
from PIL import Image
import io
import os
import numpy as np
import json
import re
from langchain_ollama import ChatOllama, OllamaEmbeddings
from langchain_core.messages import SystemMessage, HumanMessage
from langchain.schema import AIMessage
from langchain_core.runnables import RunnableLambda

# %%
def encode_image(image_path, max_size=(512, 512), quality=80):
    image = Image.open(image_path)

    # Redimensionner l'image
    image.thumbnail(max_size)

    # Convertir en bytes avec compression
    buffer = io.BytesIO()
    image.save(buffer, format="JPEG", quality=quality)

    # Encoder en Base64
    encoded_string = base64.b64encode(buffer.getvalue()).decode("utf-8")

    return encoded_string

# %%
def extract_json(response_text):
    """
    Extrait la portion JSON (délimitée par {}) de la réponse textuelle pour seulement avoir le dictionnaire et non le texte généré par l'ia.
    """
    match = re.search(r'\{.*\}', response_text, re.DOTALL)
    if match:
        json_str = match.group()
        try:
            return json.loads(json_str)
        except Exception as e:
            print(f"Erreur lors du chargement du JSON : {e}")
            return None
    else:
        print("Aucun JSON trouvé dans la réponse.")
        return None

# %%
def prompt_func(data):
    type_ = data["type"]
    text = data["text"]
    content_parts = []

    if type_ == "keywords":
        image = data["image"]
        image_part = {
            "type": "image_url",
            "image_url": f"data:image/jpeg;base64,{image}",
        }
        content_parts.append(image_part)

    #system_message = SystemMessage(content=data["system_message_text"])

    text_part = {"type": "text", "text": text}

    content_parts.append(text_part)

    human_message = HumanMessage(content=content_parts)

    #return [system_message, human_message]
    return [human_message]

# %%
def call_func(chain, prompt):
    try:
        response = chain.invoke(prompt)

        if isinstance(response, AIMessage):
            response_text = response.content
        else:
            response_text = str(response)  # Conversion en string si nécessaire

        print(f"Reponse du llm : {response_text}")

        return response_text

    except Exception as e:
        print(f"Erreur de parsing JSON : {e}. Nouvelle tentative...")
        return -1

# %%
directory = "photos_temp"
calling = LLMCall(directory)
df = calling.df
clustering_manager = ClusteringManager(df)
llm = ChatOllama(model="gemma3")

# %%
df
# Out:
#              image_name                             path            date_time  \
# 0   20240902_154612.jpg  photos_temp\20240902_154612.jpg  2024:09:02 15:46:13
# 1   20240902_154624.jpg  photos_temp\20240902_154624.jpg  2024:09:02 15:46:24
# 2   20240902_155344.jpg  photos_temp\20240902_155344.jpg  2024:09:02 15:53:44
# 3   20240902_161626.jpg  photos_temp\20240902_161626.jpg  2024:09:02 16:16:27
# 4   20240902_162507.jpg  photos_temp\20240902_162507.jpg  2024:09:02 16:25:07
# 5   20240921_131758.jpg  photos_temp\20240921_131758.jpg  2024:09:21 13:17:58
# 6   20240921_131759.jpg  photos_temp\20240921_131759.jpg  2024:09:21 13:17:59
# 7   20240921_135514.jpg  photos_temp\20240921_135514.jpg  2024:09:21 13:55:14
# 8   20240921_135526.jpg  photos_temp\20240921_135526.jpg  2024:09:21 13:55:27
# 9   20240921_135535.jpg  photos_temp\20240921_135535.jpg  2024:09:21 13:55:35
#   photos_temp\20240921_175013.jpg
# Cluster: cluster_4
#   photos_temp\20240921_175638.jpg
# Day: 2024:09:28
# Cluster: cluster_5
#   photos_temp\20240928_113104.jpg
#   photos_temp\20240928_121400.jpg
#   photos_temp\20240928_113107.jpg
#   photos_temp\20240928_121404.jpg
#   photos_temp\20240928_121356.jpg
#   photos_temp\20240928_121426.jpg
#   photos_temp\20240928_121427.jpg
#   photos_temp\20240928_122247.jpg
#   photos_temp\20240928_122240.jpg
#   photos_temp\20240928_122537.jpg
#   photos_temp\20240928_122242.jpg
#   photos_temp\20240928_122812.jpg
#   photos_temp\20240928_123427.jpg
#   photos_temp\20240928_132632.jpg
#   photos_temp\20240928_123428.jpg
# Cluster: cluster_6
#   photos_temp\20240928_132627.jpg
#   photos_temp\20240928_132640.jpg
#   photos_temp\20240928_132636.jpg
#   photos_temp\20240928_133555.jpg
#   photos_temp\20240928_132644.jpg
#   photos_temp\20240928_144039.jpg
#   photos_temp\20240928_133600.jpg
# Day: 2024:09:29
# Cluster: cluster_7
#   photos_temp\20240929_095640.jpg
# Day: 2024:10:01
# Cluster: cluster_8
#   photos_temp\20241001_081958.jpg
# Day: 2024:10:22
# Cluster: cluster_9
#   photos_temp\20241022_141718.jpg
# Day: 2024:12:28
# Cluster: cluster_10
#   photos_temp\20241228_134947.jpg
#   photos_temp\20241228_135820.jpg
#   photos_temp\20241228_143434.jpg
# Cluster: cluster_11
#   photos_temp\20241228_181743.jpg
#   photos_temp\20241228_181753.jpg
#   photos_temp\20241228_181746.jpg
# Cluster: cluster_12
#   photos_temp\20241228_181747.jpg
# Day: 2025:01:26
# Cluster: cluster_13
#   photos_temp\20250126_101956.jpg
#   photos_temp\20250126_102232.jpg
#   photos_temp\20250126_102011.jpg
#   photos_temp\20250126_102744.jpg
#   photos_temp\20250126_102226.jpg
#   photos_temp\20250126_102748.jpg
#   photos_temp\20250126_102749.jpg
#   photos_temp\20250126_113958.jpg
#   photos_temp\20250126_113955.jpg
#   photos_temp\20250126_115619.jpg
#   photos_temp\20250126_114300.jpg
# Day: 2025:02:13
# Cluster: cluster_14
#   photos_temp\20250213_165625.jpg
# Day: 2025:02:17
# Cluster: cluster_15
#   photos_temp\20250217_081138.jpg
# Day: 2025:02:19
# Cluster: cluster_16
#   photos_temp\20250219_084504.jpg

# %%
def get_representative_image(image_paths):
    embeddings = clustering_manager.image_embedding(paths=image_paths)
    all_scores = []
    for i in range(len(image_paths)):
        similarity = 0
        for j in range(len(image_paths)):
            similarity += np.dot(embeddings[i], embeddings[j])
        all_scores.append(similarity)
    best_score_index = all_scores.index(max(all_scores))
    return image_paths[best_score_index]

# %%
def list_best_images(image_paths):
    if len(image_paths) < 4:
        return image_paths
    else:
        embeddings = clustering_manager.image_embedding(paths=image_paths)
        all_scores = []
        for i in range(len(image_paths)):
            similarity = 0
            for j in range(len(image_paths)):
                similarity += np.dot(embeddings[i], embeddings[j])
            all_scores.append(similarity)
        best_score_indices = sorted(range(len(all_scores)), key=lambda i: all_scores[i], reverse=True)[:4]
        return [image_paths[i] for i in best_score_indices]

# %%
images_to_send = []
for day, day_clusters in clusters_by_day.items():
    print(f"Day: {day}")
    for cluster_name, image_paths in day_clusters.items():
        if len(image_paths) > 1:
            print(f"Cluster: {cluster_name}")
            representative_images = list_best_images(image_paths)
            print(f"Most representative image: {representative_images}")
            images_to_send.append(representative_images)
# Out:
# Day: 2024:09:02
# Cluster: cluster_1
# Most representative image: ['photos_temp\\20240902_154612.jpg', 'photos_temp\\20240902_154624.jpg', 'photos_temp\\20240902_162507.jpg', 'photos_temp\\20240902_161626.jpg']
# Day: 2024:09:21
# Cluster: cluster_2
# Most representative image: ['photos_temp\\20240921_135526.jpg', 'photos_temp\\20240921_135535.jpg', 'photos_temp\\20240921_131758.jpg', 'photos_temp\\20240921_135514.jpg']
# Cluster: cluster_3
# Most representative image: ['photos_temp\\20240921_175010.jpg', 'photos_temp\\20240921_175652.jpg', 'photos_temp\\20240921_175013.jpg']
# Day: 2024:09:28
# Cluster: cluster_5
# Most representative image: ['photos_temp\\20240928_121427.jpg', 'photos_temp\\20240928_122537.jpg', 'photos_temp\\20240928_121426.jpg', 'photos_temp\\20240928_121356.jpg']
# Cluster: cluster_6
# Most representative image: ['photos_temp\\20240928_132627.jpg', 'photos_temp\\20240928_133600.jpg', 'photos_temp\\20240928_132644.jpg', 'photos_temp\\20240928_132640.jpg']
# Day: 2024:09:29
# Day: 2024:10:01
# Day: 2024:10:22
# Day: 2024:12:28
# Cluster: cluster_10
# Most representative image: ['photos_temp\\20241228_134947.jpg', 'photos_temp\\20241228_135820.jpg', 'photos_temp\\20241228_143434.jpg']
# Cluster: cluster_11
# Most representative image: ['photos_temp\\20241228_181743.jpg', 'photos_temp\\20241228_181753.jpg', 'photos_temp\\20241228_181746.jpg']
# Day: 2025:01:26
# Cluster: cluster_13
# Most representative image: ['photos_temp\\20250126_102011.jpg', 'photos_temp\\20250126_102749.jpg', 'photos_temp\\20250126_101956.jpg', 'photos_temp\\20250126_102226.jpg']
# Day: 2025:02:13
# Day: 2025:02:17
# Day: 2025:02:19

# %%
def llm_call(image_paths, keywords_chain):
    categories = []
    for i in range(0, len(image_paths)):
        print(f"Image {i} : {image_paths[i]}")
        '''image_b64 = encode_image(image_paths[i])
        image_name = os.path.basename(image_paths[i])'''
        images_description = []
        for images in image_paths[i]:
            image_b64 = encode_image(images)
            image_name = os.path.basename(images)
            prompt = {
                "type": "keywords",
                "text": f"write a very short description  of the image",
                "image": image_b64,
            }
            output = call_func(keywords_chain, prompt)
            images_description.append(f"image description : {output}")

        prompt_text = "You'll have descriptions of images stored in the same album :"
        for description in images_description:
            prompt_text += f"\n{description}"
        prompt_text += "\nNow, please summarize the content of these images in a few words suitable for naming a vacation photo album like sports (football, tennis, badminton, bowling, hike) or activity (party, visits, yoga, etc..). Only give the response, no other text."
        print("----")
        print(prompt_text)
        print("----")
        prompt = {
            "type": "keywords",
            "text": prompt_text,
            "image": encode_image(image_paths[i][0])
        }
        output = call_func(keywords_chain, prompt)
        print("============================")
        print(f"RESULT : {output}\n")
        print("===========================")

    return categories

# %%
def pipeline_call(image_paths, df, llm):
    image_data = df
    new_image_paths = image_paths

    prompt_chain = RunnableLambda(prompt_func)
    keyword_chain = prompt_chain | llm

    image_data = llm_call(new_image_paths, keyword_chain)

    return image_data

# %%
df = pipeline_call(images_to_send, df, llm)
# Out:
# Image 0 : ['photos_temp\\20240902_154612.jpg', 'photos_temp\\20240902_154624.jpg', 'photos_temp\\20240902_162507.jpg', 'photos_temp\\20240902_161626.jpg']
# Reponse du llm : Here's a short description of the image:
#
# The image shows a small, rocky waterfall cascading into a clear stream. Lush green trees line the banks, creating a serene and natural scene.
# Reponse du llm : Here's a short description of the image:
#
# The image is a distorted, low-angle reflection of a rocky shoreline and a blue sky in a body of water. The reflection is wavy and uneven, creating a dreamlike effect.
# Reponse du llm : Here's a short description of the image:
#
# The image shows a paved pathway winding through a lush green forest. A wooden railing runs along one side of the path, leading the eye into the distance. The scene evokes a sense of a peaceful, natural trail.
# Reponse du llm : Here's a short description of the image:
#
# Two people are smiling directly at the camera, leaning against each other with their faces close. They are both wearing hats and appear to be outdoors, with a blurred green background suggesting a wooded area.
# ----
# You'll have descriptions of images stored in the same album :
# image description : Here's a short description of the image:
#
# The image shows a small, rocky waterfall cascading into a clear stream. Lush green trees line the banks, creating a serene and natural scene.
# image description : Here's a short description of the image:
#
# The image is a distorted, low-angle reflection of a rocky shoreline and a blue sky in a body of water. The reflection is wavy and uneven, creating a dreamlike effect.
# image description : Here's a short description of the image:
#
# The image shows a paved pathway winding through a lush green forest. A wooden railing runs along one side of the path, leading the eye into the distance. The scene evokes a sense of a peaceful, natural trail.
# image description : Here's a short description of the image:
#
# Two people are smiling directly at the camera, leaning against each other with their faces close. They are both wearing hats and appear to be outdoors, with a blurred green background suggesting a wooded area.
# Now, please summarize the content of these images in a few words suitable for naming a vacation photo album like sports (football, tennis, badminton, bowling, hike) or activity (party, visits, yoga, etc..). Only give the response, no other text.
# ----
# Reponse du llm : Nature Escape
# ============================
# RESULT : Nature Escape
#
# ===========================
# Image 1 : ['photos_temp\\20240921_135526.jpg', 'photos_temp\\20240921_135535.jpg', 'photos_temp\\20240921_131758.jpg', 'photos_temp\\20240921_135514.jpg']
# Reponse du llm : Here's a short description of the image:
#
# This is a fisheye-style photograph showing a canal or waterway. The sky and surrounding buildings are reflected in the water, creating a distorted, immersive view. A Ferris wheel is visible in the background.
# Reponse du llm : Here's a short description of the image:
#
# The image is a distorted, mirrored view of a waterfront scene. It shows a Ferris wheel, a green wall with autumn foliage, and a dark, rippled body of water, creating a surreal and visually interesting reflection.
# Reponse du llm : Here's a short description of the image:
#
# The image is a self-portrait taken with a camera held at arm's length. It shows a man's face and hand, with a wire sculpture of a tree in the background and a reflective surface (likely a fountain or sculpture) reflecting the surrounding greenery and sky. It has a slightly distorted, fisheye effect.
# Reponse du llm : Here's a short description of the image:
#
# A smiling man and woman are posing for a selfie, with a large Ferris wheel visible in the background. They are standing on a waterfront walkway with trees and a cloudy blue sky.
# ----
# You'll have descriptions of images stored in the same album :
# image description : Here's a short description of the image:
#
# This is a fisheye-style photograph showing a canal or waterway. The sky and surrounding buildings are reflected in the water, creating a distorted, immersive view. A Ferris wheel is visible in the background.
# image description : Here's a short description of the image:
#
# The image is a distorted, mirrored view of a waterfront scene. It shows a Ferris wheel, a green wall with autumn foliage, and a dark, rippled body of water, creating a surreal and visually interesting reflection.
# image description : Here's a short description of the image:
#
# The image is a self-portrait taken with a camera held at arm's length. It shows a man's face and hand, with a wire sculpture of a tree in the background and a reflective surface (likely a fountain or sculpture) reflecting the surrounding greenery and sky. It has a slightly distorted, fisheye effect.
# image description : Here's a short description of the image:
#
# A smiling man and woman are posing for a selfie, with a large Ferris wheel visible in the background. They are standing on a waterfront walkway with trees and a cloudy blue sky.
# Now, please summarize the content of these images in a few words suitable for naming a vacation photo album like sports (football, tennis, badminton, bowling, hike) or activity (party, visits, yoga, etc..). Only give the response, no other text.
# ----
# Reponse du llm : City Reflections
# ============================
# RESULT : City Reflections
#
# ===========================
# Image 2 : ['photos_temp\\20240921_175010.jpg', 'photos_temp\\20240921_175652.jpg', 'photos_temp\\20240921_175013.jpg']
# Reponse du llm : Here's a short description of the image:
#
# The image shows a tall, modern office building with numerous windows, set against a clear blue sky. The building is viewed from a street-level perspective, with a green bike lane visible in the foreground.
# Reponse du llm : Here's a short description of the image:
#
# The image is a distorted, upward-looking shot of a city street. Tall buildings dominate the background, and a white car is positioned on the right side of the frame. There's a concrete sidewalk and streetlights visible in the foreground.
# Reponse du llm : Here's a short description of the image:
#
# The image shows a tall, modern building with a distinctive facade of circular windows. The building is a Marriott hotel, as indicated by the hotel's logo. The shot is taken from a low angle, emphasizing the building's height and geometric design.
# ----
# You'll have descriptions of images stored in the same album :
# image description : Here's a short description of the image:
#
# The image shows a tall, modern office building with numerous windows, set against a clear blue sky. The building is viewed from a street-level perspective, with a green bike lane visible in the foreground.
# image description : Here's a short description of the image:
#
# The image is a distorted, upward-looking shot of a city street. Tall buildings dominate the background, and a white car is positioned on the right side of the frame. There's a concrete sidewalk and streetlights visible in the foreground.
# image description : Here's a short description of the image:
#
# The image shows a tall, modern building with a distinctive facade of circular windows. The building is a Marriott hotel, as indicated by the hotel's logo. The shot is taken from a low angle, emphasizing the building's height and geometric design.
# Now, please summarize the content of these images in a few words suitable for naming a vacation photo album like sports (football, tennis, badminton, bowling, hike) or activity (party, visits, yoga, etc..). Only give the response, no other text.
# ----
# Reponse du llm : Marriott Hotel
# ============================
# RESULT : Marriott Hotel
#
# ===========================
# Image 3 : ['photos_temp\\20240928_121427.jpg', 'photos_temp\\20240928_122537.jpg', 'photos_temp\\20240928_121426.jpg', 'photos_temp\\20240928_121356.jpg']
# Reponse du llm : Here's a short description of the image:
#
# The image is taken from a low angle, looking up at a stone wall and a body of water. The water reflects the trees and sky above, creating a mirrored effect. The wall is made of small, irregularly shaped stones and is partially covered with green vegetation. The sky is overcast and gray.
# Reponse du llm : Here's a short description of the image:
#
# The image captures a view looking down into a small, rocky waterfall cascading through a lush, green forest. Branches and leaves frame the scene, creating a layered and somewhat obscured perspective.
# Reponse du llm : Here's a short description of the image:
#
# The image shows a side profile of a river with a mirrored reflection in the water. On the right side, a rocky embankment is visible, covered in gray stones and some green vegetation. The sky is overcast, creating a muted, reflective effect on the water.
# Reponse du llm : Here's a short description of the image:
#
# The image depicts a serene, misty lake nestled within a forested valley. The trees are a mix of evergreen and autumnal colors, creating a beautiful contrast against the gray, overcast sky. It evokes a sense of peaceful wilderness.
# ----
# You'll have descriptions of images stored in the same album :
# image description : Here's a short description of the image:
#
# The image is taken from a low angle, looking up at a stone wall and a body of water. The water reflects the trees and sky above, creating a mirrored effect. The wall is made of small, irregularly shaped stones and is partially covered with green vegetation. The sky is overcast and gray.
# image description : Here's a short description of the image:
#
# The image captures a view looking down into a small, rocky waterfall cascading through a lush, green forest. Branches and leaves frame the scene, creating a layered and somewhat obscured perspective.
# image description : Here's a short description of the image:
#
# The image shows a side profile of a river with a mirrored reflection in the water. On the right side, a rocky embankment is visible, covered in gray stones and some green vegetation. The sky is overcast, creating a muted, reflective effect on the water.
# image description : Here's a short description of the image:
#
# The image depicts a serene, misty lake nestled within a forested valley. The trees are a mix of evergreen and autumnal colors, creating a beautiful contrast against the gray, overcast sky. It evokes a sense of peaceful wilderness.
# Now, please summarize the content of these images in a few words suitable for naming a vacation photo album like sports (football, tennis, badminton, bowling, hike) or activity (party, visits, yoga, etc..). Only give the response, no other text.
# ----
# Reponse du llm : Reflections & Waterways
# ============================
# RESULT : Reflections & Waterways
#
# ===========================
# Image 4 : ['photos_temp\\20240928_132627.jpg', 'photos_temp\\20240928_133600.jpg', 'photos_temp\\20240928_132644.jpg', 'photos_temp\\20240928_132640.jpg']
# Reponse du llm : Here's a short description of the image:
#
# The image shows a forest scene taken from a low angle, looking up at a moss-covered slope. The trees are tall and slender, creating a vertical pattern, while the moss is a vibrant green. The ground is a mix of brown earth and fallen branches.
# Reponse du llm : Here's a short description of the image:
#
# The image presents a dramatic, upward-facing view of a dense forest. A vibrant green mossy patch contrasts sharply with the dark, vertical lines of the trees, creating a striking and textured composition.
# Reponse du llm : Here's a short description of the image:
#
# A young man is hanging upside down from a tree branch, holding onto trekking poles. He's wearing a backpack and casual clothing, with a mossy tree trunk in the background.
# Reponse du llm : Here's a short description of the image:
#
# A young man is lying on his back outdoors, holding hiking poles. He is wearing a black shirt, gray backpack, and khaki pants. Behind him is a mossy, textured wall.
# ----
# You'll have descriptions of images stored in the same album :
# image description : Here's a short description of the image:
#
# The image shows a forest scene taken from a low angle, looking up at a moss-covered slope. The trees are tall and slender, creating a vertical pattern, while the moss is a vibrant green. The ground is a mix of brown earth and fallen branches.
# image description : Here's a short description of the image:
#
# The image presents a dramatic, upward-facing view of a dense forest. A vibrant green mossy patch contrasts sharply with the dark, vertical lines of the trees, creating a striking and textured composition.
# image description : Here's a short description of the image:
#
# A young man is hanging upside down from a tree branch, holding onto trekking poles. He's wearing a backpack and casual clothing, with a mossy tree trunk in the background.
# image description : Here's a short description of the image:
#
# A young man is lying on his back outdoors, holding hiking poles. He is wearing a black shirt, gray backpack, and khaki pants. Behind him is a mossy, textured wall.
# Now, please summarize the content of these images in a few words suitable for naming a vacation photo album like sports (football, tennis, badminton, bowling, hike) or activity (party, visits, yoga, etc..). Only give the response, no other text.
# ----
# Reponse du llm : Forest Adventure
# ============================
# RESULT : Forest Adventure
#
# ===========================
# Image 5 : ['photos_temp\\20241228_134947.jpg', 'photos_temp\\20241228_135820.jpg', 'photos_temp\\20241228_143434.jpg']
# Reponse du llm : Here's a short description of the image:
#
# The image shows a detailed, full-size skeleton of a *Triceratops* dinosaur. The dinosaur is posed in a defensive stance, with its prominent horns and frill clearly visible. It's displayed in a museum setting with informational panels.
# Reponse du llm : Here's a short description of the image:
#
# The image shows a dinosaur skull, likely a Triceratops, mounted on a museum display. The skull is brown and has prominent horns. The background is a dark gray wall with a display panel containing information about the dinosaur.
# Reponse du llm : Here's a short description of the image:
#
# The image shows a large, spherical model of the Earth. It displays the continents and oceans in shades of blue and brown, giving a realistic representation of our planet. The model is set against a geometric, light-colored background.
# ----
# You'll have descriptions of images stored in the same album :
# image description : Here's a short description of the image:
#
# The image shows a detailed, full-size skeleton of a *Triceratops* dinosaur. The dinosaur is posed in a defensive stance, with its prominent horns and frill clearly visible. It's displayed in a museum setting with informational panels.
# image description : Here's a short description of the image:
#
# The image shows a dinosaur skull, likely a Triceratops, mounted on a museum display. The skull is brown and has prominent horns. The background is a dark gray wall with a display panel containing information about the dinosaur.
# image description : Here's a short description of the image:
#
# The image shows a large, spherical model of the Earth. It displays the continents and oceans in shades of blue and brown, giving a realistic representation of our planet. The model is set against a geometric, light-colored background.
# Now, please summarize the content of these images in a few words suitable for naming a vacation photo album like sports (football, tennis, badminton, bowling, hike) or activity (party, visits, yoga, etc..). Only give the response, no other text.
# ----
# Reponse du llm : Dinosaurs
# ============================
# RESULT : Dinosaurs
#
# ===========================
# Image 6 : ['photos_temp\\20241228_181743.jpg', 'photos_temp\\20241228_181753.jpg', 'photos_temp\\20241228_181746.jpg']
# Reponse du llm : Here's a short description of the image:
#
# A person is holding a cat in their arms, leaning against a dark-colored door. There's a plant and some shelves with books and small objects in the background.
# Reponse du llm : Here's a short description of the image:
#
# A person is holding a small, white and orange cat close to their body, leaning against a dark background with a plant in the foreground. The person is wearing a black jacket and jeans.
# Reponse du llm : Here's a short description of the image:
#
# A woman with dark hair and glasses is lying on a dark surface, holding a small white and gray cat. She's wearing jeans and a dark shirt, and a gray blanket is draped over her. There's a plant and some framed pictures in the background.
# ----
# You'll have descriptions of images stored in the same album :
# image description : Here's a short description of the image:
#
# A person is holding a cat in their arms, leaning against a dark-colored door. There's a plant and some shelves with books and small objects in the background.
# image description : Here's a short description of the image:
#
# A person is holding a small, white and orange cat close to their body, leaning against a dark background with a plant in the foreground. The person is wearing a black jacket and jeans.
# image description : Here's a short description of the image:
#
# A woman with dark hair and glasses is lying on a dark surface, holding a small white and gray cat. She's wearing jeans and a dark shirt, and a gray blanket is draped over her. There's a plant and some framed pictures in the background.
# Now, please summarize the content of these images in a few words suitable for naming a vacation photo album like sports (football, tennis, badminton, bowling, hike) or activity (party, visits, yoga, etc..). Only give the response, no other text.
# ----
# Reponse du llm : Relaxing
# ============================
# RESULT : Relaxing
#
# ===========================
# Image 7 : ['photos_temp\\20250126_102011.jpg', 'photos_temp\\20250126_102749.jpg', 'photos_temp\\20250126_101956.jpg', 'photos_temp\\20250126_102226.jpg']
# Reponse du llm : Here's a short description of the image:
#
# The image shows a blurred, snow-covered road receding into the distance, framed by the side window of a vehicle. The scene is dominated by a hazy, gray-white color palette, creating a sense of winter weather and limited visibility.
# Reponse du llm : Here's a short description of the image:
#
# The image shows a snow-covered road winding through a dense forest. The scene is shrouded in snow, creating a blurred and wintry atmosphere. It appears to be taken from inside a vehicle.
# Reponse du llm : Here’s a short description of the image:
#
# The image shows a blurred, snowy landscape with a road stretching into the distance. A dark vehicle’s side mirror is visible on the right side of the frame, creating a distorted reflection of the trees and road. The overall effect is one of a hazy, snowy day.
# Reponse du llm : Here's a short description of the image:
#
# The image shows a blurred view through a car's side window. A tree with dense, dark branches is visible in the foreground, partially obscured by the snow or mist outside. The overall effect is a hazy, wintry scene.
# ----
# You'll have descriptions of images stored in the same album :
# image description : Here's a short description of the image:
#
# The image shows a blurred, snow-covered road receding into the distance, framed by the side window of a vehicle. The scene is dominated by a hazy, gray-white color palette, creating a sense of winter weather and limited visibility.
# image description : Here's a short description of the image:
#
# The image shows a snow-covered road winding through a dense forest. The scene is shrouded in snow, creating a blurred and wintry atmosphere. It appears to be taken from inside a vehicle.
# image description : Here’s a short description of the image:
#
# The image shows a blurred, snowy landscape with a road stretching into the distance. A dark vehicle’s side mirror is visible on the right side of the frame, creating a distorted reflection of the trees and road. The overall effect is one of a hazy, snowy day.
# image description : Here's a short description of the image:
#
# The image shows a blurred view through a car's side window. A tree with dense, dark branches is visible in the foreground, partially obscured by the snow or mist outside. The overall effect is a hazy, wintry scene.
# Now, please summarize the content of these images in a few words suitable for naming a vacation photo album like sports (football, tennis, badminton, bowling, hike) or activity (party, visits, yoga, etc..). Only give the response, no other text.
# ----
# Reponse du llm : Winter drive
# ============================
# RESULT : Winter drive
#
# ===========================
